# %%
from sunpy import lightcurve as lc
import bayesflare as bf
import pandas as pd
import pyfits as fits
import matplotlib.pyplot as pl
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Infuriatingly, the SunPy interface only downloads the data, and doesn't perform the corrections, so we need to pull the data out of IDL.

# %%
corr_data = fits.open('data/hsi_crtd_20100804_000000_48hrs.fits')

# %%
corr_data[2].header
# Out:
# XTENSION= 'BINTABLE'           /Binary table written by MWRFITS v1.11b
# BITPIX  =                    8 /Required value
# NAXIS   =                    2 /Required value
# NAXIS1  =              3759061 /Number of bytes per row
# NAXIS2  =                    1 /Number of rows
# PCOUNT  =                    0 /Normally 0 (no varying arrays)
# GCOUNT  =                    1 /Required value
# TFIELDS =                    5 /Number of columns in table
# COMMENT
# COMMENT  *** End of mandatory fields ***
# COMMENT
# COMMENT
# COMMENT  *** Column names ***
# COMMENT
# TTYPE1  = 'TIMES   '           /
# TTYPE2  = 'DATA    '           /
# TTYPE3  = 'DATA_ID '           /
# TTYPE4  = 'FLAGS   '           /
# TTYPE5  = 'FLAG_IDS'           /
# COMMENT
# COMMENT  *** Column formats ***
# COMMENT
# TFORM1  = '820800A '           /
# TFORM2  = '388800E '           /
# TFORM3  = '117A    '           /
# TFORM4  = '1382400B'           /
# TFORM5  = '544A    '           /
# COMMENT
# COMMENT  *** Column dimensions (2 D or greater) ***
# COMMENT
# TDIM1   = '(19, 43200)'        /
# TDIM2   = '( 9, 43200)'        /
# TDIM3   = '(13, 9) '           /
# TDIM4   = '( 32, 43200)'       /
# TDIM5   = '(17, 32)'           /

# %%
fig = plt.figure(figsize=(18, 7))
data = corr_data[1].data[0][0]
time = [datetime.datetime.strptime(a, '%Y-%m-%dT%H:%M:%S') for a in data]
#pl.plot(x, corr_data[1].data[0][1])
#data = np.transpose(corr_data[1].data[0][1])
data = corr_data[1].data[0][1]
data = pd.DataFrame(data, index=time, columns=[u'3 - 6 keV', u'6 - 12 keV', u'12 - 25 keV', u'25 - 50 keV', u'50 - 100 keV', u'100 - 300 keV', u'300 - 800 keV', u'800 - 7000 keV', u'7000 - 20000 keV'])

# %%
# Behold, a most dirty of hacks
start = '2014-08-04 00:00'
end = '2014-08-06 00:00'
rhessi = lc.RHESSISummaryLightCurve.create(start, end)
rhessi.data = data

# %%
fig = plt.figure()
#rhessi = rhessi[]
rhessi.data['6 - 12 keV'].plot(fig = fig, figsize=(18, 7))

# %%
import pylightcurve as lc

# %%
curve = lc.Lightcurve()

# %%
meta = {}
for column in rhessi.data.columns:
    meta[column] = rhessi.meta
curve.import_data(rhessi.data, meta)
curve.clc = curve.data['6 - 12 keV']

# %%
dcurve = curve.detrend(method='savitzkygolay', nbins=401, order=3, column='6 - 12 keV')
dcurve = dcurve.detrend(method='savitzkygolay', nbins=401, order=3, column='3 - 6 keV')
dcurve.data = dcurve.data.drop([u'12 - 25 keV', u'25 - 50 keV', u'50 - 100 keV', u'100 - 300 keV', u'300 - 800 keV', u'800 - 7000 keV', u'7000 - 20000 keV'], axis=1)

# %%
dcurve.peek()

# %%
dcurve.data.plot()

# %%
bglen = 401
noiseestmethod='powerspectrum'
psestfrac=0.5
flareparams={'taugauss': (0,  20*60, 5), 
             'tauexp'  : (0, 5*60*60, 60)}
odds = bf.OddsRatioDetector( 
                            curve.interpolate(),
                            bglen=bglen,
                            bgorder=3,
                            noiseestmethod='powerspectrum',
                            tvsigma=1,
                            psestfrac=0.5,
                            flareparams=flareparams,
                            noisepoly=True,
                            noiseimpulse=True,
                            noiseimpulseparams={'t0': (0, (bglen-1.)*curve.dt(), bglen)},
                            noiseexpdecay=False,
                            noiseexpdecayparams={'tauexp': (600, 3*60*60, 6)},
                            noiseexpdecaywithreverse=True,
                            ignoreedges=False,
                            edgelength=10
                            )
odds_out = odds.oddsratio()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-92-cdfd5486a6bd> in <module>()
#      21                             edgelength=10
#      22                             )
# ---> 23 odds_out = odds.oddsratio()
#
# /home/daniel/repositories/bayesflare/bayesflare/finder/find.py in oddsratio(self)
#     794                                                          noiseestmethod=self.noiseestmethod,
#     795                                                          psestfrac=self.psestfrac,
# --> 796                                                          tvsigma=self.tvsigma)
#     797
#     798                 noiseodds.append(Bg)
#
# /home/daniel/repositories/bayesflare/bayesflare/stats/bayes.py in bayes_factors_marg_poly_bgd_only(self, bglen, bgorder, noiseestmethod, psestfrac, tvsigma)
#     459             tmpcurve.detrend(method='savitzkygolay', nbins=bglen, order=bgorder)
#     460         if noiseestmethod == 'powerspectrum':
# --> 461           sk = estimate_noise_ps(tmpcurve, estfrac=psestfrac)[0]
#     462         elif noiseestmethod == 'tailveto':
#     463             print "Noise only", tvsigma, len(tmpcurve.clc), type(tmpcurve.clc)
#
# /home/daniel/repositories/bayesflare/bayesflare/noise/noise.py in estimate_noise_ps(lightcurve, estfrac, **kwargs)
#      50                 sk, f = lightcurve.psd(reduced=reduced)
#      51             else:
# ---> 52                 sk, f = lightcurve.psd()
#      53     # get the power spectrum of the lightcurve data
#      54
#
# /home/daniel/repositories/lightcurve/pylightcurve/lightcurve.py in psd(self, **kwargs)
#     329         if isinstance(data, pd.core.frame.DataFrame):
#     330             # If the supplied data is a pandas DataFrame we'll need to
# --> 331             # decide if we're working on just one column, or all of them.
#     332             if "column" in kwargs:
#     333                 column = kwargs["column"]
#
# AttributeError: Lightcurve instance has no attribute 'default'

# %%
# Load all of the odds ratio data into the Lightcurve
times = dcurve.data.index.tolist()
odds_data = pd.DataFrame(index=times)
odds_array = odds_out[0]
#odds_array = np.pad(odds_out[0],(int(21/4),int(21/4)), mode='minimum')
odds_data['xrsa'] = odds_array

data = dcurve.add_highlight(odds_data)

curve = dcurve

# %%
# %config InlineBackend.figure_format = 'png'
fig, ax = plt.subplots(1,1,figsize=(13,4), frameon=False, dpi=300)

ax.set_xlabel('Time')
ax.set_yscale('log')
ax.plot(data.data.index, data.data['6 - 12 keV'], alpha=0)
ax.set_ylim(1e-9, 1e-5)
pl.setp( ax.xaxis.get_majorticklabels(), rotation=90 )
ymin, ymax = ax.get_ybound()
xmin, xmax = ax.get_xbound()

stuff = np.array(data.highlight.xrsa)
threshold = 7.027591
stuff[stuff<threshold] = -100
stuff[stuff>=threshold] = -99
image = np.zeros((100,len(stuff)))
image[:,:] = stuff

ax1 = ax.twinx()
ax1.patch.set_visible(False)
ax1.set_yscale('log')
#ax1.set_ylim(1e-9, 1e-5)
#ax1.set_ylim(9e-7, 1e-6)
#ax1.set_ylabel('1.0--8.0 $\AA$ | Watts m$^-2$')
ax1.set_yticks(())
#ax1.set_ylabel('0.5--4.0 $\AA$ | Watts m$^-2$')
ax1.plot(data.data.index, data.data['3 - 6 keV'], alpha=1, color='#9d261d')

ax2 = ax.twinx()#.twiny()
if not len(data.highlight) == 0:
    ax2.imshow(image, origin='lower', cmap='RdPu', extent=[xmin, xmax, ymin, ymax], alpha=.1)
ax2.set_yscale('log')
ax2.set_yticks(())
ax2.patch.set_visible(False)
#ax2.yaxis.set_ticks_position((''))
#ax2.tick_params(axis='y', colors='blue')
ax2.plot(data.data.index, data.data['6 - 12 keV'], color='#049cdb', alpha=1)

spines_to_remove = ['top', 'right']
for spine in spines_to_remove:
    ax.spines[spine].set_visible(False)
almost_black = '#262626'
spines_to_keep = ['bottom', 'left']
for spine in spines_to_keep:
    ax.spines[spine].set_linewidth(0.5)
    ax.spines[spine].set_color(almost_black)    
#ax.grid(True)
ax.yaxis.grid(True, which="major", linestyle='-', color=almost_black, linewidth=0.15)

if data.tags:
    data.plot_tags(ax, 'peak_time', 'class')
# Out:
# aspect is not supported for Axes with xscale=linear, yscale=log
# Images are not supported on non-linear axes.
# aspect is not supported for Axes with xscale=linear, yscale=log
# Images are not supported on non-linear axes.

# %%
data.highlight
# Out:
#                           xrsa
# 2010-08-04 00:00:00       -inf
# 2010-08-04 00:00:04       -inf
# 2010-08-04 00:00:08       -inf
# 2010-08-04 00:00:12       -inf
# 2010-08-04 00:00:16       -inf
# 2010-08-04 00:00:20       -inf
# 2010-08-04 00:00:24       -inf
# 2010-08-04 00:00:28       -inf
# 2010-08-04 00:00:32       -inf
# 2010-08-04 00:00:36       -inf
# 2010-08-04 00:00:40       -inf
# 2010-08-04 00:00:44       -inf
# 2010-08-04 00:00:48       -inf
# 2010-08-04 00:00:52       -inf
# 2010-08-04 00:00:56       -inf
# 2010-08-04 00:01:00       -inf
# 2010-08-04 00:01:04       -inf
# 2010-08-04 00:01:08       -inf
# 2010-08-04 00:01:12       -inf
# 2010-08-04 00:01:16       -inf
# 2010-08-04 00:01:20       -inf
# 2010-08-04 00:01:24       -inf
# 2010-08-04 00:01:28       -inf
# 2010-08-04 00:01:32       -inf
# 2010-08-04 00:01:36       -inf
# 2010-08-04 00:01:40       -inf
# 2010-08-04 00:01:44       -inf
# 2010-08-04 00:01:48   9.408175
# 2010-08-04 00:01:52  12.453468
# 2010-08-04 00:01:56  12.587535
# ...                        ...
# 2010-08-04 23:58:00   8.142730
# 2010-08-04 23:58:04  11.848784
# 2010-08-04 23:58:08  15.909063
# 2010-08-04 23:58:12       -inf
# 2010-08-04 23:58:16       -inf
# 2010-08-04 23:58:20       -inf
# 2010-08-04 23:58:24       -inf
# 2010-08-04 23:58:28       -inf
# 2010-08-04 23:58:32       -inf
# 2010-08-04 23:58:36       -inf
# 2010-08-04 23:58:40       -inf
# 2010-08-04 23:58:44       -inf
# 2010-08-04 23:58:48       -inf
# 2010-08-04 23:58:52       -inf
# 2010-08-04 23:58:56       -inf
# 2010-08-04 23:59:00       -inf
# 2010-08-04 23:59:04       -inf
# 2010-08-04 23:59:08       -inf
# 2010-08-04 23:59:12       -inf
# 2010-08-04 23:59:16       -inf
# 2010-08-04 23:59:20       -inf
# 2010-08-04 23:59:24       -inf
# 2010-08-04 23:59:28       -inf
# 2010-08-04 23:59:32       -inf
# 2010-08-04 23:59:36       -inf
# 2010-08-04 23:59:40       -inf
# 2010-08-04 23:59:44       -inf
# 2010-08-04 23:59:48       -inf
# 2010-08-04 23:59:52       -inf
# 2010-08-04 23:59:56       -inf
#
# [21600 rows x 1 columns]

# %%
rhessi.meta
# Out:
# OrderedDict([('SIMPLE', True), ('BITPIX', 8), ('NAXIS', 0), ('EXTEND', True), ('DATE', '2014-03-02'), ('ORIGIN', 'sundog'), ('OBSERVER', 'hessiops'), ('TELESCOP', 'HESSI'), ('OBJECT', 'Sun'), ('DATE_OBS', '2014-03-01T00:00:00.000'), ('DATE_END', '2014-03-02T00:00:00.000')])

# %%
rhessi.peek()
# Out:
# matplotlib is currently using a non-GUI backend, so cannot show the figure

# %%
import sunpy

# %%
sunpy.__version__
# Out:
# '0.5.0'

# %%
import astropy

# %%
astropy.__version__
# Out:
# '0.3.2'
