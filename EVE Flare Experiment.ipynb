# %%
import sunpy, sunpy.lightcurve
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
eve = sunpy.lightcurve.EVELightCurve.create('2014/06/20')

# %%
eve.peek(figsize=(13,6))
