# %%
import sunpy, sunpy.lightcurve
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
eve = sunpy.lightcurve.EVELightCurve.create('2012/06/20')
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.py:615: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators; you can avoid this warning by specifying engine='python'.
#   ParserWarning)

# %%
eve.peek()
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/figure.py:371: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
